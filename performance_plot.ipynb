# %%
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

df = pd.read_csv("experiments/068e4488-0bd3-11f0-b5fe-ef7347101099/history.csv")
df.sort_values("val_ndcg@5")
# Out:
#    epoch  train_loss  train_ndcg@1  train_ndcg@5  train_ndcg@10  val_loss  \
# 0      1    0.126159      0.230469      0.512741       0.581917  0.094511
# 1      2    0.066183      0.452148      0.708732       0.730220  0.067706
# 2      3    0.041614      0.601562      0.805370       0.815566  0.061196
# 4      5    0.026586      0.699219      0.865249       0.868223  0.056851
# 3      4    0.032282      0.643555      0.834810       0.839772  0.058968
#
#    val_ndcg@1  val_ndcg@5  val_ndcg@10
# 0    0.301563    0.592682     0.637262
# 1    0.419922    0.695719     0.715207
# 2    0.473828    0.721984     0.746256
# 4    0.521484    0.748504     0.770894
# 3    0.539453    0.751895     0.771474
